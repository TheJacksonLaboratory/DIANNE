# %%
# %load_ext autoreload
# %autoreload 2
import sys
DIANNE = ".."
sys.path.insert(0, f"{DIANNE}/dianne-core")
sys.path.insert(0, f"{DIANNE}/dianne-utils")
import dianne_core
import dianne_utils as dianne
dianne.setNotebookWidth(100)

# %%
# Download the demo data from Zenodo and unzip it to the data folder
dianne.downloadZIPFromZenodo('../../data/', 'https://zenodo.org/records/19225051/files/', 'RMS2194.oid0.zip')

# %%
# Run ROI selection interactive interface
thumbsDir = '../../data/RMS2194.oid0'
samples  = ['thumbnail']
dianne.runSelection(thumbsDir, samples, ext='jpeg')

# %%
# View the selected ROIs on the thumbnails
sample = samples[0]
dianne.viewSelection(thumbsDir, sample, sample+'-0', ext='jpeg')
dianne.viewSelection(thumbsDir, sample, sample+'-1', ext='jpeg')
