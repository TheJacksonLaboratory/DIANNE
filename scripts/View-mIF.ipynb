# %%
# %load_ext autoreload
# %autoreload 2
import sys
DIANNE = ".."
sys.path.insert(0, f"{DIANNE}/dianne-core")
sys.path.insert(0, f"{DIANNE}/dianne-utils")
sys.path.insert(0, f"{DIANNE}/dianne-viewer")
import dianne_core
import dianne_utils as dianne
import dianne_viewer as viewer
dianne.setNotebookWidth(100)

# %%
imgs = {'HuBMAP PhenoCycler lung': 'https://assets.hubmapconsortium.org/cbd3adc472cb3f43bbdebd83204af337/ometiff-pyramids/pipeline_output/expr/reg001_expr.ome.tif',
        'SenNet H&E mouse kidney': 'https://assets.api.sennetconsortium.org/9c42f0549cf389e58275081b0fb1bec2/ometiff-pyramids/lab_processed/images/SN-73368-K.ome.tif',
        'HuBMAP PAS kidney': 'https://assets.hubmapconsortium.org/f37584fa1a38fc8e0e2c212c15e8bd7e/ometiff-pyramids/lab_processed/images/VAN0049-RK-2-17-PAS.ome.tif',
        'SenNet H&E human kidney': 'https://assets.api.sennetconsortium.org/197d48084f77947d90cf2f4ae485acc9/ometiff-pyramids/lab_processed/images/SL250376-HS250512_0015918-011.ome.tif',
        'SenNet H&E human pancreas': 'https://assets.api.sennetconsortium.org/4c4a550f40d39fc0aca062c813c83534/ometiff-pyramids/lab_processed/images/JDC_WP_026_b.ome.tif',
       }

viewer.create_viewer(sorted(list(imgs.keys())), imgs);
