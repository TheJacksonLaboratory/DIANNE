# %%
# %load_ext autoreload
# %autoreload 2
import sys
DIANNE = ".."
sys.path.insert(0, f"{DIANNE}/dianne-core")
sys.path.insert(0, f"{DIANNE}/dianne-utils")
sys.path.insert(0, f"{DIANNE}/dianne-viewer")
import dianne_core
import dianne_utils as dianne
import dianne_viewer as viewer
dianne.setNotebookWidth(100)

# %%
viewer.create_viewer(None, {'HuBMAP PhenoCycler lung': 'https://assets.hubmapconsortium.org/cbd3adc472cb3f43bbdebd83204af337/ometiff-pyramids/pipeline_output/expr/reg001_expr.ome.tif'});
