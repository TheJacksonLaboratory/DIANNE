# %%
import sys
sys.path.append('..')
import viewer

viewer.viewSTQ('/projects/activities/kappsen-tmc/USERS/domans/Fetal-membranes-analysis/STQ-results',
               load_features=False, classifierPaths=None);
