# %%
import sys
DIANNE = ".."
sys.path.insert(0, f"{DIANNE}/dianne-core")
sys.path.insert(0, f"{DIANNE}/dianne-utils")
sys.path.insert(0, f"{DIANNE}/dianne-viewer")
import dianne_viewer

dianne_viewer.viewSTQ('/projects/activities/kappsen-tmc/USERS/domans/Fetal-membranes-analysis/STQ-results',
               load_features=False, classifierPaths=None);
