# %%
import sys
DIANNE = "/opt/DIANNE/"
sys.path.insert(0, f"{DIANNE}/scripts/PDX/")
from utils import dianne, viewer, samples, viewSamples
dianne.setNotebookWidth(100)

viewer.samplePicker()

# %%
drawings = viewSamples(samples=samples)
