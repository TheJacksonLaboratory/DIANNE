# %%
import sys
DIANNE = "/opt/DIANNE/"
sys.path.insert(0, f"{DIANNE}/scripts/PDX/")
from utils import dianne, viewer, samples, viewSamples, getMetaDict
dianne.setNotebookWidth(100)

viewer.samplePicker(getMetaDict())

# %%
viewSamples(samples=samples);
