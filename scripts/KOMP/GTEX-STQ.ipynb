# %%
# %load_ext autoreload
# %autoreload 2

import os, json, sys
DIANNE = "/projects/activities/komp-histopath/USERS/domans/DIANNE"
sys.path.insert(0, f"{DIANNE}/dianne-core")
sys.path.insert(0, f"{DIANNE}/dianne-utils")
sys.path.insert(0, f"{DIANNE}/dianne-viewer")
import dianne_core
import dianne_utils as dianne
import dianne_viewer as viewer
dianne.setNotebookWidth(100)
import pandas as pd

projectDir = '/projects/activities/komp-histopath'

classifierPaths = f'{projectDir}/annotations/GTEX-round1/'
if not os.path.exists(classifierPaths):
    os.makedirs(classifierPaths)

tissues_mapping = {'kidney': ['Renal cortex',
                              'Renal medulla'],
                   'pancreas': ['Pancreas'],
                   'heart': ['Heart'],
                   'lung': ['Lung'],
                   'spleen': ['Spleen'],
                   'liver': ['Liver'],}

df_metadata_all = pd.read_csv(f'{projectDir}/USERS/domans/GTEX-normal-slides/gtex-histology-merged.csv', index_col=0)

tissue = 'kidney'

wh = df_metadata_all['PrimaryAnatomicStructures'].isin(tissues_mapping[tissue])
df_metadata = df_metadata_all.loc[wh].copy()
other_cols = [c for c in df_metadata.columns if c not in ["Pathology Categories", "Pathology Notes"]]
new_order = other_cols[:2] + ["Pathology Categories", "Pathology Notes"] + other_cols[2:]
df_metadata = df_metadata[new_order]
df_metadata = df_metadata.drop(['SpecimenDetailedDescription', 'SeriesInstanceUID', 'crdc_series_uuid', 'PathologyNotes', 'pindex'], axis=1)

dataPath = f'{projectDir}/USERS/domans/GTEX-normal-slides/results-batch-{tissue}/'
samples = sorted([s for s in os.listdir(dataPath) if not 'pipeline' in s]) #[:100]
# samples = ['GTEX-1A8G7-1625.oid0', 'GTEX-1B8SF-2425.oid5', 'GTEX-14JFF-2125.oid1']
sample_metadata = {s: df_metadata.loc[s.split('.oid')[0]].to_dict() for s in samples}


# {s: sample_metadata[s]['Pathology Notes'] for s in samples if s.endswith('oid0')}

kidney_sel_samples = ['GTEX-111VG-0625.oid0', 'GTEX-117YW-1225.oid0', 'GTEX-11DXY-1725.oid0', 'GTEX-11EQ8-2225.oid0', 'GTEX-11GS4-2325.oid0', 'GTEX-11GSP-0825.oid0', 'GTEX-11ILO-1725.oid0', 'GTEX-11NUK-1625.oid0', 'GTEX-11PRG-2225.oid0', 'GTEX-11TTK-1925.oid0', 'GTEX-11TUW-0825.oid0', 
                       'GTEX-11WQC-1425.oid0', 'GTEX-11ZVC-1025.oid0', 'GTEX-1212Z-1625.oid0', 'GTEX-1269C-1725.oid0', 'GTEX-12WSB-1925.oid0', 'GTEX-12WSG-0825.oid0', 'GTEX-12WSH-1325.oid0', 'GTEX-12ZZZ-1025.oid0', 'GTEX-1313W-2525.oid0', 'GTEX-1314G-1125.oid0', 'GTEX-132Q8-1525.oid0', 
                       'GTEX-1339X-0925.oid0', 'GTEX-1399S-0525.oid0', 'GTEX-1399T-1125.oid0', 'GTEX-139TS-0725.oid0', 'GTEX-139TU-1725.oid0', 'GTEX-13FHO-2325.oid0', 'GTEX-13FLV-0825.oid0', 'GTEX-13FTY-1625.oid0', 'GTEX-13FTZ-1225.oid0', 'GTEX-13FXS-1825.oid0', 'GTEX-13G51-1325.oid0', 
                       'GTEX-13IVO-1625.oid0', 'GTEX-13JUV-1225.oid0', 'GTEX-13JVG-1825.oid0', 'GTEX-13N1W-2125.oid0', 'GTEX-13NZA-1825.oid0', 'GTEX-13O1R-2525.oid0', 'GTEX-13OVI-1125.oid0', 'GTEX-13OVJ-2125.oid0', 'GTEX-13OW6-1825.oid0', 'GTEX-13OW8-0925.oid0', 'GTEX-13PDP-2325.oid0', 
                       'GTEX-13PVQ-2425.oid0', 'GTEX-13QIC-1125.oid0', 'GTEX-13QJC-1225.oid0', 'GTEX-13S7M-1025.oid0', 'GTEX-13SLX-1525.oid0', 'GTEX-13VXU-2525.oid0', 'GTEX-13W46-2325.oid0', 'GTEX-13X6I-1925.oid0', 'GTEX-13YAN-2425.oid0', 'GTEX-144FL-1825.oid0', 'GTEX-144GO-1825.oid0', 
                       'GTEX-145LU-1825.oid0', 'GTEX-145MG-2025.oid0', 'GTEX-145MH-1925.oid0', 'GTEX-145MI-2125.oid0', 'GTEX-14753-1825.oid0', 'GTEX-1477Z-2425.oid0', 'GTEX-147GR-1625.oid0', 'GTEX-148VI-0925.oid0', 'GTEX-14A5H-2525.oid0', 'GTEX-14ASI-2225.oid0', 'GTEX-14C5O-2025.oid0', 
                       'GTEX-14JFF-2125.oid0', 'GTEX-14LZ3-2125.oid0', 'GTEX-14PHW-2125.oid0', 'GTEX-14PJO-2125.oid0', 'GTEX-15CHQ-2125.oid0', 'GTEX-15CHS-1725.oid0', 'GTEX-15D79-2225.oid0', 'GTEX-15DCD-1925.oid0', 'GTEX-15EOM-1425.oid0', 'GTEX-15G19-1725.oid0', 'GTEX-15G1A-1125.oid0', 
                       'GTEX-15SHU-2025.oid0', 'GTEX-15SHW-2425.oid0', 'GTEX-15SKB-1825.oid0', 'GTEX-15UF6-1725.oid0', 'GTEX-16GPK-1725.oid0', 'GTEX-16MT9-2225.oid0', 'GTEX-16NPX-2025.oid0', 'GTEX-16XZY-1025.oid0', 'GTEX-17F96-1925.oid0', 'GTEX-17F97-1925.oid0', 'GTEX-17HHY-2325.oid0', 
                       'GTEX-17MF6-1925.oid0', 'GTEX-18A7B-1625.oid0', 'GTEX-18D9B-1825.oid0', 'GTEX-19HZE-1825.oid0', 'GTEX-1A3MW-2225.oid0', 'GTEX-1A3MX-1725.oid0', 'GTEX-1A8FM-2025.oid0', 'GTEX-1A8G6-2225.oid0', 'GTEX-1A8G7-1625.oid0', 'GTEX-1AX8Z-2325.oid0', 'GTEX-1AX9I-2525.oid0', 
                       'GTEX-1N5O9-1925.oid0', 'GTEX-1NV5F-2125.oid0', 'GTEX-1OJC4-2325.oid0', 'GTEX-1P4AB-1625.oid0', 'GTEX-1PPGY-2325.oid0', 'GTEX-1QEPI-1725.oid0', 'GTEX-1QP6S-1525.oid0', 'GTEX-1R46S-1625.oid0', 'GTEX-1R7EV-1625.oid0', 'GTEX-1R9PO-1625.oid0', 'GTEX-1RAZS-2425.oid0', 
                       'GTEX-1RDX4-2725.oid0', 'GTEX-1RNSC-2025.oid0', 'GTEX-1S82P-1225.oid0', 'GTEX-NFK9-1825.oid0', 'GTEX-NFK9-1925.oid0', 'GTEX-NL3G-1225.oid0', 'GTEX-NL3G-1325.oid0', 'GTEX-NL3H-1925.oid0', 'GTEX-NL3H-2025.oid0', 'GTEX-NL4W-2125.oid0', 'GTEX-NL4W-2225.oid0', 
                       'GTEX-NPJ7-2325.oid0', 'GTEX-NPJ7-2425.oid0', 'GTEX-O5YU-1525.oid0', 'GTEX-OHPN-1425.oid0', 'GTEX-OXRN-0925.oid0', 'GTEX-OXRN-1025.oid0', 'GTEX-POYW-1525.oid0', 'GTEX-PWO3-0725.oid0', 'GTEX-QDVN-1625.oid0', 'GTEX-QDVN-1725.oid0', 'GTEX-QVUS-1025.oid0', 
                       'GTEX-R3RS-1725.oid0', 'GTEX-R45C-1825.oid0', 'GTEX-R55F-2325.oid0', 'GTEX-RN64-1525.oid0', 'GTEX-RVPV-0725.oid0', 'GTEX-SIU7-0725.oid0', 'GTEX-T2YK-1725.oid0', 'GTEX-TKQ2-0325.oid0', 'GTEX-TSE9-2025.oid0', 'GTEX-U412-2225.oid0', 'GTEX-U412-2325.oid0', 
                       'GTEX-U8T8-1725.oid0', 'GTEX-UTHO-2325.oid0', 'GTEX-VJWN-2025.oid0', 'GTEX-W5X1-1625.oid0', 'GTEX-WOFL-1825.oid0', 'GTEX-WVJS-2225.oid0', 'GTEX-X4EO-1825.oid0', 'GTEX-X4XX-2325.oid0', 'GTEX-X585-2125.oid0', 'GTEX-X8HC-2125.oid0', 'GTEX-XLM4-1425.oid0', 
                       'GTEX-XMD1-1925.oid0', 'GTEX-XMD2-2025.oid0', 'GTEX-XOT4-1725.oid0', 'GTEX-Y5V5-1225.oid0', 'GTEX-YJ89-2125.oid0', 'GTEX-ZE9C-1425.oid0', 'GTEX-ZF3C-2225.oid0', 'GTEX-ZLFU-0925.oid0', 'GTEX-ZVE1-2225.oid0', 'GTEX-ZVE2-2225.oid0', 'GTEX-ZVT3-2325.oid0', 
                       'GTEX-ZVZP-0925.oid0', 'GTEX-ZXG5-2025.oid0', 'GTEX-ZYFC-2525.oid0', 'GTEX-ZYFG-1625.oid0']
samples = kidney_sel_samples.copy()
print(f"Loading data from {len({s.split('.oid')[0] for s in samples})} slides")

viewer.viewSTQkomp(dataPath, samples, load_features=True, F=2, classifierPaths=classifierPaths,
                   save_path=classifierPaths, sample_metadata=sample_metadata, mpp=0.5, username='auto');
