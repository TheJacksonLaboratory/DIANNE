# %%
# %load_ext autoreload
# %autoreload 2
import sys
DIANNE = ".."
sys.path.insert(0, f"{DIANNE}/dianne-core")
sys.path.insert(0, f"{DIANNE}/dianne-utils")
sys.path.insert(0, f"{DIANNE}/dianne-viewer")
import dianne_core
import dianne_utils as dianne
import dianne_viewer as viewer

# %%
dpath = '/projects/activities/kappsen-tmc/placental-development-project/codex'
imgs = {
    '1543-A':      f'{dpath}/SL260197-PC26028_1543-A/ome/PC26028_Scan1.er.ome.tiff',
    '3146-pA-M':   f'{dpath}/SL260181-PC26018_3146-pA-M/ome/PC26018_Scane1.ome.tiff',
    '3146-pB-F':   f'{dpath}/SL260182-PC26019_3146-pB-F/ome/PC26019_Scan1.er.ome.tiff',
}

viewer.create_viewer(sorted(list(imgs.keys())), imgs);
