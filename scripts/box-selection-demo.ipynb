# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
sys.path.append("/projects/activities/kappsen-tmc/USERS/domans/differential-annotator-dev/image-differential-annotator/annotator/")
from selection import runSelection, viewSelection

# %%
thumbs = '/projects/activities/kappsen-tmc/histology/placenta/thumbs/test'

# samples = sorted([f for f in os.listdir(thumbs) if f.endswith('.tiff')])[::-1]
samples  = ['MC_PLACM_0001', 'MC_PLACM_0003']
print(samples)

runSelection(thumbs, samples)

# %%
for sample in samples:
    viewSelection(thumbs, sample)
