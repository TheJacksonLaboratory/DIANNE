# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
import dianne
import viewer
dianne.setNotebookWidth(100)

# %%
dataPath = '/projects/activities/kappsen-tmc/xenium-5k/placenta-histology/ome'
imgsr = {'PLACM-11': f'{dataPath}/SL250383-HS260144_0027504-PLACM-0011.ome.tif',
         'PLACM-03': f'{dataPath}/SL250383-HS260144_0027504-PLACM-0003.ome.tif'}
drawings = viewer.create_viewer(list(imgsr.keys()), imgsr, height="900px")[1]
